# %%
import pandas as pd

comisiones = pd.read_excel('./Met-cuantTarea2.xlsx', sheet_name='Sheet2', header = 1, skiprows=1)
comisiones.head()
# Out:
#     3.9
# 0   5.7
# 1   7.3
# 2  10.6
# 3  13.0
# 4  13.6

# %%
from scipy import stats

coeficiente = scipy.stats.skew(comisiones, axis=0, bias=True)

print("El coeficiente es:", coeficiente)
# Out:
# El coeficiente es: [2.16766226]

# %%
if coeficiente == 0:
    print("Tiene distribución normal")
if coeficiente > 0:
    print("Mas peso en la cola izquierda de la distribución")
if coeficiente < 0:
    print("Mas peso en la cola derecha de la distribución")
# Out:
# Mas peso en la cola izquierda de la distribución

# %%
comisiones.hist()
# Out:
# array([[<AxesSubplot:title={'center':'3.9'}>]], dtype=object)
